# %% [markdown]
# # Project Overview
# - What I hope to achieve:
# - World domination

# %%
import pandas as pd
import numpy as np 
import warnings
import sklearn as sk
import seaborn as sns; sns.set(color_codes=True)

warnings.filterwarnings(action='ignore', category=UserWarning, module='gensim')
# %matplotlib inline

# %%
# Out:
# ShuffleSplit(n_splits=3, random_state=111, test_size=0.25, train_size=None)

# %%
data_in = pd.read_csv('deceptive-opinion.csv')
data_in.head()
# Out:
#   deceptive   hotel  polarity       source  \
# 0  truthful  conrad  positive  TripAdvisor
# 1  truthful   hyatt  positive  TripAdvisor
# 2  truthful   hyatt  positive  TripAdvisor
# 3  truthful    omni  positive  TripAdvisor
# 4  truthful   hyatt  positive  TripAdvisor
#
#                                                 text
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as I'm finally catchi...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...

# %%
data_in.pivot_table(
    columns=['deceptive','polarity'],
    index = ['hotel'],
    aggfunc = len).fillna(0)
# Out:
#                     source                                 text           \
# deceptive        deceptive          truthful          deceptive
# polarity          negative positive negative positive  negative positive
# hotel
# affinia                 20       20       20       20        20       20
# allegro                 20       20       20       20        20       20
# amalfi                  20       20       20       20        20       20
# ambassador              20       20       20       20        20       20
# conrad                  20       20       20       20        20       20
# fairmont                20       20       20       20        20       20
# hardrock                20       20       20       20        20       20
# hilton                  20       20       20       20        20       20
# homewood                20       20       20       20        20       20
# hyatt                   20       20       20       20        20       20
# intercontinental        20       20       20       20        20       20
# james                   20       20       20       20        20       20
# knickerbocker           20       20       20       20        20       20
# monaco                  20       20       20       20        20       20
# omni                    20       20       20       20        20       20
# palmer                  20       20       20       20        20       20
# sheraton                20       20       20       20        20       20
# sofitel                 20       20       20       20        20       20
# swissotel               20       20       20       20        20       20
# talbott                 20       20       20       20        20       20
#
#
# deceptive        truthful
# polarity         negative positive
# hotel
# affinia                20       20
# allegro                20       20
# amalfi                 20       20
# ambassador             20       20
# conrad                 20       20
# fairmont               20       20
# hardrock               20       20
# hilton                 20       20
# homewood               20       20
# hyatt                  20       20
# intercontinental       20       20
# james                  20       20
# knickerbocker          20       20
# monaco                 20       20
# omni                   20       20
# palmer                 20       20
# sheraton               20       20
# sofitel                20       20
# swissotel              20       20
# talbott                20       20

# %%
train, validate, test = np.split(data_in.sample(frac=1,random_state=100), [int(.6*len(data_in)), int(.8*len(data_in))])

validate.head()
# Out:
#       deceptive     hotel  polarity       source  \
# 913    truthful  sheraton  negative          Web
# 1065   truthful    monaco  negative          Web
# 576   deceptive  hardrock  positive        MTurk
# 208    truthful  hardrock  positive  TripAdvisor
# 672   deceptive   sofitel  positive        MTurk
#
#                                                    text
# 913   My wife and I stayed here for a weekend in Chi...
# 1065  My wife and I brought our daughter downtown fo...
# 576   While making the obligatory trip to the Chicag...
# 208   Just putting in a good word for the Hard Rock ...
# 672    If you are traveling anywhere near Lake Michi...

# %%
# Out:
#       deceptive             hotel  polarity       source  \
# 1254  deceptive            conrad  negative        MTurk
# 1087   truthful            monaco  negative          Web
# 822    truthful          fairmont  negative          Web
# 1514  deceptive            hilton  negative        MTurk
# 902    truthful          sheraton  negative          Web
# 1150   truthful            amalfi  negative          Web
# 1441  deceptive           sofitel  negative        MTurk
# 354    truthful            amalfi  positive  TripAdvisor
# 1153   truthful  intercontinental  negative          Web
# 1005   truthful           affinia  negative          Web
# 929    truthful          sheraton  negative          Web
# 991    truthful          hardrock  negative          Web
# 216    truthful          hardrock  positive  TripAdvisor
# 719   deceptive           sofitel  positive        MTurk
# 1115   truthful           sofitel  negative          Web
# 771   deceptive  intercontinental  positive        MTurk
# 1078   truthful             james  negative          Web
# 626   deceptive          hardrock  positive        MTurk
# 534   deceptive          homewood  positive        MTurk
# 785   deceptive            amalfi  positive        MTurk
# 1541  deceptive            palmer  negative        MTurk
# 932    truthful     knickerbocker  negative          Web
# 275    truthful            hilton  positive  TripAdvisor
# 390    truthful           allegro  positive  TripAdvisor
# 570   deceptive           affinia  positive        MTurk
# 416   deceptive             hyatt  positive        MTurk
# 560   deceptive           talbott  positive        MTurk
# 1467  deceptive            monaco  negative        MTurk
# 886    truthful         swissotel  negative          Web
# 1391  deceptive          hardrock  negative        MTurk
# ...         ...               ...       ...          ...
# 782   deceptive            palmer  positive        MTurk
# 317    truthful           sofitel  positive  TripAdvisor
# 1455  deceptive            monaco  negative        MTurk
# 49     truthful          fairmont  positive  TripAdvisor
# 135    truthful         swissotel  positive  TripAdvisor
# 835    truthful          fairmont  negative          Web
# 603   deceptive          hardrock  positive        MTurk
# 1028   truthful        ambassador  negative          Web
# 612   deceptive          hardrock  positive        MTurk
# 757   deceptive            amalfi  positive        MTurk
# 1165   truthful           allegro  negative          Web
# 897    truthful         swissotel  negative          Web
# 415   deceptive             hyatt  positive        MTurk
# 386    truthful  intercontinental  positive  TripAdvisor
# 86     truthful         swissotel  positive  TripAdvisor
# 1117   truthful           sofitel  negative          Web
# 1531  deceptive  intercontinental  negative        MTurk
# 912    truthful         swissotel  negative          Web
# 1340  deceptive          sheraton  negative        MTurk
# 1252  deceptive          fairmont  negative        MTurk
# 280    truthful            hilton  positive  TripAdvisor
# 752   deceptive  intercontinental  positive        MTurk
# 1009   truthful           affinia  negative          Web
# 802    truthful             hyatt  negative          Web
# 1550  deceptive            amalfi  negative        MTurk
# 53     truthful              omni  positive  TripAdvisor
# 350    truthful            amalfi  positive  TripAdvisor
# 79     truthful            conrad  positive  TripAdvisor
# 792   deceptive           allegro  positive        MTurk
# 1544  deceptive  intercontinental  negative        MTurk
